# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import re 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/drive/My Drive/BTL_DataMining/BT_2/BT2.csv")
data.describe()
data['Gender'].value_counts().plot.pie(explode=[0,0.1], shadow=True)

# %%
row = ["Favorite Color", "Favorite Music Genre", "Favorite Beverage", "Favorite Soft Drink"]
for i in row:
    plt.figure(figsize=(10, 4))
    sns.countplot(y = i, hue = "Gender", data = data)
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

data1 = data.copy(deep = True)
le_color = LabelEncoder()
data1['Favorite Color'] = le_color.fit_transform(data['Favorite Color'])

le_genre = LabelEncoder()
data1['Favorite Music Genre'] = le_genre.fit_transform(data['Favorite Music Genre'])


le_beverage = LabelEncoder()
data1['Favorite Beverage'] = le_beverage.fit_transform(data['Favorite Beverage'])


le_drink = LabelEncoder()
data1['Favorite Soft Drink'] = le_drink.fit_transform(data['Favorite Soft Drink'])


le_gender = LabelEncoder()
data1['Gender'] = le_gender.fit_transform(data['Gender'])

# %%
data1.head()
# Out:
#    Favorite Color  Favorite Music Genre  ...  Favorite Soft Drink  Gender
# 0               0                     6  ...                    0       0
# 1               1                     2  ...                    1       0
# 2               2                     6  ...                    1       0
# 3               2                     1  ...                    2       0
# 4               0                     6  ...                    1       0
#
# [5 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth = 5)

X = data1.drop(['Gender'], axis = 1)
y = data1.Gender 

clf.fit(X, y)
clf.score(X, y)
# Out:
# 0.8484848484848485

# %%
import graphviz
dot_data = tree.export_graphviz(clf, out_file=None,feature_names=data1.drop(['Gender'],axis=1).columns, filled=True) 
graph = graphviz.Source(dot_data) 
graph

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(max_depth=5, min_samples_split=6)
clf = clf.fit(X, y)
clf.score(X, y)
# Out:
# 0.803030303030303

# %%
import graphviz 
dot_data = tree.export_graphviz(clf, out_file=None,feature_names=data1.drop(['Gender'],axis=1).columns, filled=True) 
graph = graphviz.Source(dot_data) 
graph

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier(max_depth=5, min_samples_split=6, min_samples_leaf=5)
clf = clf.fit(X, y)
clf.score(X, y)
# Out:
# 0.7575757575757576

# %%
dot_data = tree.export_graphviz(clf, out_file=None,feature_names=data1.drop(['Gender'],axis=1).columns, filled=True) 
graph = graphviz.Source(dot_data) 
graph
